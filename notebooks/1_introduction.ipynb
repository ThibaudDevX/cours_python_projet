# %% [markdown]
# # 🐍 Introduction à Python
#
# ---
#
# ## 📌 1. C'est quoi un Jupyter Notebook ?
# Les cours de cet enseignement utiliseront les Jupyter Notebooks comme support, mais qu'est-ce que c'est ?
# La page sur laquelle tu te trouve est un notebook, il te permet de lire ce cours et de coder au même endroit ! Plus besoin de quitter ton navigateur et de jongler entre ton IDE et ton cours !
#
# Tu peux modifier les notebooks à ta guise en cliquant sur la zone que tu souhaites éditer puis en cliquant sur le crayon qui apparait en haut à droite.
# Tu peux aussi ajouter des zones de texte ou de code en cliquant sur les boutons en haut à gauche avec les +.
#
# Si tu le souhaites tu peux directement importer tes notebooks sur ton drive google en cliquant sur le bouton dans la barre d'outil, comme ça tout tes cours sont sauvergardé en ligne ! (sur téléphone cette fonctionnalité est disponible en ouvrant le site sur version pour l'ordinateur)
#
# Les notebooks utilisent le markdown pour la mise en forme, si tu veux avoir les bases pour modifier tes notebooks comme tu le souhaites je te conseille d'aller jeter un coup d'oeil ici : https://www.markdownguide.org/basic-syntax/.
#
# ---
#
# ## 📌 2. Un premier regard sur ce langage polyvalent
#
# Python est un langage de programmation populaire, utilisé dans le développement web, la data science, l’intelligence artificielle, la finance, les sciences économiques et cognitives.
#
# ---
#
# ## 📌 3. Qu'est-ce qu'un langage de programmation ?
# Un langage de programmation est un outil permettant de donner des instructions à un ordinateur.
#
# ### Langages compilés vs interprétés
# - Langages compilés (ex: C, C++) → Exécutés après compilation en code machine.
# - Langages interprétés (ex: Python, JavaScript) → Exécutés ligne par ligne.
#
# Python est un langage interprété, ce qui le rend plus flexible et accessible.
#
# ---
#
# ## 📌 4. Python en un coup d'œil
# Python a été créé en 1991 par Guido van Rossum et est devenu l’un des langages les plus utilisés dans le monde.
#
# ### Caractéristiques de Python :
# - Syntaxe claire et lisible
# - Typage dynamique (pas besoin de déclarer les types)
# - Extensible avec des milliers de bibliothèques
# - Très utilisé en Data Science et Machine Learning
#
# ---
#
# ## 📌 5. Avantages et Inconvénients de Python
# |    Avantages     |   Inconvénients  |
# |------------------|------------------|
# | Facile à apprendre | Moins rapide que C/C++ |
# | Large écosystème de bibliothèques | Consommation mémoire élevée |
# | Interprété et portable | Pas idéal pour les systèmes embarqués |
# | Très utilisé en Data Science | Faible en applications mobiles |
#
# Python est puissant et polyvalent, mais pas toujours optimal pour les applications nécessitant de la performance brute.
#
# ---
#
# ## 📌 6. Comparaison rapide : Python vs Java
# | Critère | Python | Java |
# |---------|----------|--------|
# | Facilité d’apprentissage | Très simple | Plus complexe |
# | Exécution | Interprété | Compilé (plus rapide) |
# | Typage | Dynamique | Statique |
# | Utilisation | IA, Data Science, Web | Applications lourdes, Android |
#
# Python est souvent préféré pour les tâches d’analyse de données et Machine Learning, tandis que Java est plus utilisé pour les applications d’entreprise.
#
# ---
#
# ## 📌 7. Python en Sciences Économiques et Cognitives
# Python est très utilisé en finance, économie et sciences cognitives.
#
# ### En Sciences Économiques :
# - Analyse financière : Étude des tendances de marché, prévisions économiques.
# - Trading algorithmique : Automatisation des décisions d’achat/vente en bourse.
# - Modélisation statistique : Régressions économiques et machine learning.
# - Gestion des risques bancaires : Détection de fraudes et scoring de crédit.
#
# ### En Sciences Cognitives :
# - Analyse EEG et IRMf : Étude de l’activité cérébrale.
# - Modèles de réseaux neuronaux : Simulation du cerveau humain.
# - Eye-tracking : Analyse des mouvements oculaires pour la recherche UX.
# - Traitement du langage naturel (NLP) : Étude de la compréhension du langage humain.
#
# ---
#
# ## 📌 8. Exécution d'un premier programme en Python
# Le classique Hello, World! est souvent la première chose qu’on exécute en Python. Pour cela on utilise la fonction print() et les quotes ' ' ou " " pour rentrer le texte que tu souhaites afficher.
#
# ```python
# print("Hello, World!")
# ```
#
# Essaye dans la cellule ci-dessous !

# %% [markdown]
# En python les print s'affichent ligne par ligne.
# ```python
# print("H")
# print("E")
# print("L")
# print("L")
# print("O")
#
# H
# E
# L
# L
# O
# ```
#
# Essaye de faire dessiner cette chouette :
# ```
#  ()_()
# ( •,• )
# (")_(")
#
# ```
# Choississez bien entre ' ' et " " !
